# %% [markdown]
# <a href="https://colab.research.google.com/github/hhwwan/Programmers_Dev_Cource/blob/main/5%EC%9D%BC%EC%B0%A8_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **환경 설정**

# %%
# !pip install ipython-sql==0.4.1
# !pip install SQLAlchemy==1.4.49
# Out:
# Collecting ipython-sql==0.4.1
#   Downloading ipython_sql-0.4.1-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable<1 (from ipython-sql==0.4.1)
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython>=1.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (7.34.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (2.0.36)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (0.5.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (1.17.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=1.0->ipython-sql==0.4.1)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=1.0->ipython-sql==0.4.1) (4.9.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=0.6.7->ipython-sql==0.4.1) (3.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=1.0->ipython-sql==0.4.1) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=1.0->ipython-sql==0.4.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql==0.4.1) (0.2.13)
# Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.8 MB/s eta 0:00:00
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13696 sha256=944a6a2c90f37a02cb0a9633ad8b016514f65cf63766a2d17d4c977ffd5b8e22
#   Stored in directory: /root/.cache/pip/wheels/25/4b/07/18c5d92824315576e478206ea69df34a9e31958f6143eb0e31
# Successfully built prettytable
# Installing collected packages: prettytable, jedi, ipython-sql
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.12.0
#     Uninstalling prettytable-3.12.0:
#       Successfully uninstalled prettytable-3.12.0
#   Attempting uninstall: ipython-sql
#     Found existing installation: ipython-sql 0.5.0
#     Uninstalling ipython-sql-0.5.0:
#       Successfully uninstalled ipython-sql-0.5.0
# Successfully installed ipython-sql-0.4.1 jedi-0.19.2 prettytable-0.7.2
# Collecting SQLAlchemy==1.4.49
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy==1.4.49) (3.1.1)
# Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.9 MB/s eta 0:00:00
# Installing collected packages: SQLAlchemy
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# Successfully installed SQLAlchemy-1.4.49

# %% [markdown]
# ## 강의에서는 guest의 패스워드를 "Guest1!*"이라고 이야기했지만 그 뒤에 "Guest1234"로 변경했습니다.

# %%
# ID와 PW를 자신의 환경에 맞게 수정
# %sql postgresql://ID:PW@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev

# %%
# %load_ext sql

# %% [markdown]
# ## 사용자별로 처음 채널과 마지막 채널 알아내기

# %%
# %%sql
#
# WITH first AS (
#    SELECT userid, ts, channel, ROW_NUMBER() OVER(PARTITION BY userid ORDER BY ts) seq
#    FROM raw_data.user_session_channel usc
#    JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# ), last AS (
#    SELECT userid, ts, channel, ROW_NUMBER() OVER(PARTITION BY userid ORDER BY ts DESC) seq
#    FROM raw_data.user_session_channel usc
#    JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# )
# SELECT first.userid AS userid, first.channel AS first_channel, last.channel AS last_channel
# FROM first
# JOIN last ON first.userid = last.userid and last.seq = 1
# WHERE first.seq = 1;

# %%
# %%sql
#
# SELECT first.userid AS userid, first.channel AS first_channel, last.channel AS last_channel
# FROM (
#   SELECT userid, ts, channel, ROW_NUMBER() OVER(PARTITION BY userid ORDER BY ts) seq
#   FROM raw_data.user_session_channel usc
#   JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# ) first
# JOIN (
#   SELECT userid, ts, channel, ROW_NUMBER() OVER(PARTITION BY userid ORDER BY ts DESC) seq
#   FROM raw_data.user_session_channel usc
#   JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# )  last ON first.userid = last.userid and last.seq = 1
# WHERE first.seq = 1;

# %%
# %%sql
#
# SELECT userid,
#  MAX(CASE WHEN rn1 = 1 THEN channel END) first_touch,
#  MAX(CASE WHEN rn2 = 1 THEN channel END) last_touch
# FROM (
#   SELECT userid,
#     channel,
#     (ROW_NUMBER() OVER (PARTITION BY usc.userid ORDER BY  st.ts asc)) AS rn1,
#     (ROW_NUMBER() OVER (PARTITION BY usc.userid ORDER BY  st.ts desc)) AS rn2
#   FROM raw_data.user_session_channel usc
#   JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# )
# GROUP BY 1;

# %%
# %%sql
#
# SELECT DISTINCT
#     A.userid,
#     FIRST_VALUE(A.channel) over(partition by A.userid order by B.ts
# rows between unbounded preceding and unbounded following) AS First_Channel,
#     LAST_VALUE(A.channel) over(partition by A.userid order by B.ts
# rows between unbounded preceding and unbounded following) AS Last_Channel
# FROM raw_data.user_session_channel A
# LEFT JOIN raw_data.session_timestamp B ON A.sessionid = B.sessionid
# ORDER BY 1;

# %% [markdown]
# ## Gross Revenue가 가장 큰 UserID 10개 찾기

# %%
# %%sql
#
# SELECT
#     userID,
#     SUM(amount)
# FROM raw_data.session_transaction st
# LEFT JOIN raw_data.user_session_channel usc ON st.sessionid = usc.sessionid
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 10;

# %%
# %%sql
#
# SELECT DISTINCT
#     usc.userid,
#     SUM(amount) OVER(PARTITION BY usc.userid)
# FROM raw_data.user_session_channel AS usc
# JOIN raw_data.session_transaction AS revenue ON revenue.sessionid = usc.sessionid
# ORDER BY 2 DESC
# LIMIT 10;

# %% [markdown]
# ## raw_data.nps 테이블을 바탕으로 월별 NPS 계산

# %%
# %%sql
#
# SELECT month,
#   ROUND((promoters-detractors)::float/total_count*100, 2) AS overall_nps
# FROM (
#   SELECT LEFT(created, 7) AS month,
#     COUNT(CASE WHEN score >= 9 THEN 1 END) AS promoters,
#     COUNT(CASE WHEN score <= 6 THEN 1 END) AS detractors,
#     COUNT(CASE WHEN score > 6 AND score < 9 THEN 1 END) As passives,
#     COUNT(1) AS total_count
#   FROM raw_data.nps
#   GROUP BY 1
#   ORDER BY 1
# );

# %%
# %%sql
#
# SELECT LEFT(created_at, 7) AS month,
#   ROUND(SUM(CASE
#     WHEN score >= 9 THEN 1
#     WHEN score <= 6 THEN -1 END)::float*100/COUNT(1), 2)
# FROM raw_data.nps
# GROUP BY 1
# ORDER BY 1;

# %% [markdown]
# ## 트랜잭션

# %%
# %%sql
#
# DROP TABLE IF EXISTS adhoc.donghwan_name_gender;
# CREATE TABLE adhoc.donghwan_name_gender (
#   name varchar(32) primary key,
#   gender varchar(16)
# );
# INSERT INTO adhoc.donghwan_name_gender VALUES ('Ben', 'Male'), ('Maddie', 'Female');
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# Done.
# Done.
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT *
# FROM adhoc.donghwan_name_gender;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('Ben', 'Male'), ('Maddie', 'Female')]

# %%
import psycopg2

# Redshift connection 함수
def get_Redshift_connection(autocommit):
    host = "learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com"
    redshift_user = "guest"
    redshift_pass = "Guest1234"
    port = 5439
    dbname = "dev"
    conn = psycopg2.connect("dbname={dbname} user={user} host={host} password={password} port={port}".format(
        dbname=dbname,
        user=redshift_user,
        password=redshift_pass,
        host=host,
        port=port
    ))
    conn.set_session(autocommit=autocommit)
    return conn

# %% [markdown]
# ### INSERT SQL을 autocommit=False로 실행

# %%
conn = get_Redshift_connection(False)
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM adhoc.donghwan_name_gender;")
res = cur.fetchall()
for r in res:
  print(r)
# Out:
# ('Ben', 'Male')
# ('Maddie', 'Female')

# %%
cur.execute("DELETE FROM adhoc.donghwan_name_gender;")

# %%
cur.execute("SELECT * FROM adhoc.donghwan_name_gender;")
res = cur.fetchall()
for r in res:
  print(r)

# %%
cur.execute("INSERT INTO adhoc.donghwan_name_gender VALUES ('Keeyong', 'Male');")

# %%
cur.execute("SELECT * FROM adhoc.donghwan_name_gender;")
res = cur.fetchall()
for r in res:
  print(r)
# Out:
# ('Keeyong', 'Male')

# %%
cur.execute("COMMIT;")   # conn.commit()는 동일한 결과를 가져옴. cur.execute("ROLLBACK;") conn.rollback()

# %%
conn.close()

# %% [markdown]
# ### INSERT SQL을 autocommit=False로 실행하고 psycopg2로 컨트롤하기

# %%
conn = get_Redshift_connection(False)
cur = conn.cursor()

# %%
try:
  cur.execute("DELETE FROM adhoc.keeyong_name_gender;")
  cur.execute("INSERT INTO adhoc.keeyong_name_gender VALUES ('Claire', 'Female');")
  conn.commit()
except (Exception, psycopg2.DatabaseError) as error:
  print(error)
  conn.rollback()
finally :
  conn.close()
# Out:
# permission denied for relation keeyong_name_gender

# %% [markdown]
# ### INSERT SQL을 autocommit=True로 실행하고 SQL로 컨트롤하기

# %%
conn = get_Redshift_connection(True)
cur = conn.cursor()

# %%
cur.execute("BEGIN;")
cur.execute("DELETE FROM adhoc.donghwan_name_gender;")
cur.execute("INSERT INTO adhoc.donghwan_name_gender VALUES ('Benjamin', 'Male');")
cur.execute("END;")

# %% [markdown]
# ### 잘못된 SQL을 중간에 실행해보기

# %%
cur.execute("BEGIN;")
cur.execute("DELETE FROM adhoc.donghwan_name_gender;")
cur.execute("INSERT INTO adhoc.donghwan_name_gender2 VALUES ('Andrew', 'Male');")
cur.execute("END;")
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# <ipython-input-43-fe36f28f6d28> in <cell line: 3>()
#       1 cur.execute("BEGIN;")
#       2 cur.execute("DELETE FROM adhoc.donghwan_name_gender;")
# ----> 3 cur.execute("INSERT INTO adhoc.donghwan_name_gender2 VALUES ('Andrew', 'Male');")
#       4 cur.execute("END;")
#
# UndefinedTable: relation "adhoc.donghwan_name_gender2" does not exist

# %% [markdown]
# ## 기타 고급 문법 소개

# %% [markdown]
# ### EXCEPT 사용해보기 - 두 개의 SELECT 문의 결과 혹은 두 개의 테이블을 비교하는데 사용.
#  * 기존 요약 테이블의 로직을 수정하는 경우 수정 전후를 비교하거나 하는데 많이 사용됨. QA용으로 아주 유용함
#  * 각 SELECT문의 필드들의 수와 타입이 동일해야함
#  * EXCEPT 대신 MINUS를 사용해도 됨

# %% [markdown]
# ### UNION: 여러 SELECT 문을 합쳐서 하나의 SELECT를 생성 (합집합)
#
# * 각 SELECT문의 필드들의 수와 타입이 동일해야함
# * UNION과 UNION ALL의 차이점은?
#   * UNION은 중복되는 레코드를 제거함
# * 다른 소스에서 생긴 레코드들을 묶어서 새로운 테이블들을 만들 때 아주 유용
#   * 예를 들면 물건 판매를 Shopify와 Amazon에 동시에 한다면 각 사이트에서 판매 레코드들을 UNION으로 묶어서 새로운 테이블을 생성가능 (CTAS)

# %%
# %%sql
#
# SELECT 'donghwan' as first_name, 'kim' as last_name
#
# UNION
#
# SELECT 'elon', 'musk'
#
# UNION
#
# SELECT 'donghwan', 'kim'
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 2 rows affected.
# [('donghwan', 'kim'), ('elon', 'musk')]

# %%
# %%sql
#
# SELECT 'donghwan' as first_name, 'kim' as last_name
#
# UNION ALL
#
# SELECT 'elon', 'musk'
#
# UNION ALL
#
# SELECT 'donghwan', 'kim'
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 3 rows affected.
# [('donghwan', 'kim'), ('elon', 'musk'), ('donghwan', 'kim')]

# %% [markdown]
# ### INTERSECT: SELECT 문들에서 공통적인 레코드를 돌려줌 (교집합)

# %% [markdown]
# ### LISTAGG - GROUP BY Aggregate 함수 중의 하나

# %%
# %%sql
#
# SELECT userid, LISTAGG(channel) WITHIN GROUP (ORDER BY ts) channels
# FROM raw_data.user_session_channel usc
# JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# GROUP BY 1
# LIMIT 10;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(27, 'YoutubeGoogleNaverFacebookFacebookGoogleGoogleFacebookOrganicOrganicOrganicOrganicFacebookNaverNaverOrganicGoogleInstagramGoogleNaverFacebookFacebook ... (829 characters truncated) ... beYoutubeFacebookYoutubeFacebookFacebookInstagramGoogleFacebookNaverOrganicInstagramFacebookInstagramGoogleFacebookYoutubeOrganicNaverGoogleInstagram'),
#  (29, 'NaverYoutubeGoogleFacebookNaverGoogleOrganicOrganicGoogleOrganicInstagramOrganicFacebookGoogleNaverInstagramNaverYoutubeInstagramGoogleNaverYoutubeYo ... (285 characters truncated) ... ookInstagramFacebookNaverInstagramNaverFacebookOrganicGoogleInstagramNaverInstagramInstagramYoutubeFacebookInstagramOrganicYoutubeOrganicOrganicNaver'),
#  (33, 'GoogleInstagramInstagramInstagramOrganicNaverNaverNaverFacebookOrganicInstagramYoutubeNaverNaverInstagramYoutubeFacebookYoutubeInstagramOrganicNaverI ... (1281 characters truncated) ... amYoutubeFacebookNaverGoogleFacebookOrganicNaverYoutubeOrganicYoutubeYoutubeNaverYoutubeNaverFacebookGoogleFacebookInstagramGoogleOrganicNaverYoutube'),
#  (40, 'YoutubeYoutubeNaverGoogleNaverNaverYoutubeYoutubeFacebookNaverYoutubeInstagramNaverOrganicOrganicOrganicYoutubeYoutubeGoogleGoogleNaverNaverYoutubeFa ... (1398 characters truncated) ... cNaverGoogleYoutubeGoogleGoogleInstagramYoutubeFacebookInstagramInstagramNaverGoogleFacebookYoutubeNaverInstagramInstagramYoutubeYoutubeOrganicGoogle'),
#  (44, 'NaverYoutubeFacebookYoutubeYoutubeGoogleNaverFacebookInstagramInstagramInstagramGoogleOrganicNaverFacebookYoutubeYoutubeInstagramOrganicNaverYoutubeYoutubeInstagramGoogleNaverGoogleNaverOrganicYoutubeInstagram'),
#  (59, 'InstagramOrganicNaverInstagramGoogleYoutubeNaverFacebookYoutubeYoutubeYoutubeFacebookFacebookNaverInstagramOrganicInstagramOrganicFacebookYoutubeGoog ... (807 characters truncated) ... averYoutubeFacebookOrganicInstagramNaverNaverInstagramNaverGoogleNaverFacebookInstagramGoogleNaverYoutubeNaverNaverGoogleGoogleOrganicGoogleInstagram'),
#  (68, 'YoutubeGoogleInstagramYoutubeInstagramInstagramInstagramOrganicInstagramYoutubeGoogleGoogleOrganic'),
#  (87, 'YoutubeYoutubeFacebookNaverFacebookYoutubeInstagramNaverFacebookGoogleYoutubeFacebookYoutubeYoutubeFacebookYoutubeYoutubeGoogleFacebookYoutubeInstagr ... (401 characters truncated) ... verFacebookGoogleYoutubeOrganicInstagramGoogleFacebookNaverOrganicOrganicNaverOrganicGoogleNaverYoutubeNaverYoutubeGoogleInstagramOrganicGoogleGoogle'),
#  (97, 'OrganicFacebookInstagramOrganicOrganicNaverInstagramFacebookYoutubeInstagramOrganicGoogleFacebookNaverYoutubeGoogleInstagramFacebookGoogleInstagramGo ... (924 characters truncated) ... eInstagramInstagramNaverGoogleYoutubeInstagramYoutubeInstagramNaverFacebookYoutubeInstagramFacebookOrganicGoogleInstagramGoogleYoutubeFacebookOrganic'),
#  (113, 'OrganicOrganicOrganicOrganicInstagramGoogleFacebookYoutubeOrganicFacebookNaverOrganicFacebookFacebookYoutubeOrganicNaverInstagramGoogleFacebookYoutub ... (1201 characters truncated) ... beFacebookNaverNaverOrganicGoogleNaverNaverNaverOrganicFacebookOrganicGoogleNaverFacebookInstagramNaverGoogleNaverGoogleFacebookYoutubeOrganicOrganic')]

# %%
# %%sql
#
# SELECT userid, LISTAGG(channel, '->') WITHIN GROUP (ORDER BY ts) channels
# FROM raw_data.user_session_channel usc
# JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# GROUP BY 1
# LIMIT 10;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 10 rows affected.
# [(27, 'Youtube->Google->Naver->Facebook->Facebook->Google->Google->Facebook->Organic->Organic->Organic->Organic->Facebook->Naver->Naver->Organic->Google->In ... (1145 characters truncated) ... ->Facebook->Instagram->Google->Facebook->Naver->Organic->Instagram->Facebook->Instagram->Google->Facebook->Youtube->Organic->Naver->Google->Instagram'),
#  (29, 'Naver->Youtube->Google->Facebook->Naver->Google->Organic->Organic->Google->Organic->Instagram->Organic->Facebook->Google->Naver->Instagram->Naver->Yo ... (447 characters truncated) ... am->Naver->Facebook->Organic->Google->Instagram->Naver->Instagram->Instagram->Youtube->Facebook->Instagram->Organic->Youtube->Organic->Organic->Naver'),
#  (33, 'Google->Instagram->Instagram->Instagram->Organic->Naver->Naver->Naver->Facebook->Organic->Instagram->Youtube->Naver->Naver->Instagram->Youtube->Faceb ... (1723 characters truncated) ... ok->Organic->Naver->Youtube->Organic->Youtube->Youtube->Naver->Youtube->Naver->Facebook->Google->Facebook->Instagram->Google->Organic->Naver->Youtube'),
#  (40, 'Youtube->Youtube->Naver->Google->Naver->Naver->Youtube->Youtube->Facebook->Naver->Youtube->Instagram->Naver->Organic->Organic->Organic->Youtube->Yout ... (1886 characters truncated) ... >Instagram->Youtube->Facebook->Instagram->Instagram->Naver->Google->Facebook->Youtube->Naver->Instagram->Instagram->Youtube->Youtube->Organic->Google'),
#  (44, 'Naver->Youtube->Facebook->Youtube->Youtube->Google->Naver->Facebook->Instagram->Instagram->Instagram->Google->Organic->Naver->Facebook->Youtube->Youtube->Instagram->Organic->Naver->Youtube->Youtube->Instagram->Google->Naver->Google->Naver->Organic->Youtube->Instagram'),
#  (59, 'Instagram->Organic->Naver->Instagram->Google->Youtube->Naver->Facebook->Youtube->Youtube->Youtube->Facebook->Facebook->Naver->Instagram->Organic->Ins ... (1125 characters truncated) ... >Naver->Naver->Instagram->Naver->Google->Naver->Facebook->Instagram->Google->Naver->Youtube->Naver->Naver->Google->Google->Organic->Google->Instagram'),
#  (68, 'Youtube->Google->Instagram->Youtube->Instagram->Instagram->Instagram->Organic->Instagram->Youtube->Google->Google->Organic'),
#  (87, 'Youtube->Youtube->Facebook->Naver->Facebook->Youtube->Instagram->Naver->Facebook->Google->Youtube->Facebook->Youtube->Youtube->Facebook->Youtube->You ... (597 characters truncated) ... tagram->Google->Facebook->Naver->Organic->Organic->Naver->Organic->Google->Naver->Youtube->Naver->Youtube->Google->Instagram->Organic->Google->Google'),
#  (97, 'Organic->Facebook->Instagram->Organic->Organic->Naver->Instagram->Facebook->Youtube->Instagram->Organic->Google->Facebook->Naver->Youtube->Google->In ... (1272 characters truncated) ... Youtube->Instagram->Youtube->Instagram->Naver->Facebook->Youtube->Instagram->Facebook->Organic->Google->Instagram->Google->Youtube->Facebook->Organic'),
#  (113, 'Organic->Organic->Organic->Organic->Instagram->Google->Facebook->Youtube->Organic->Facebook->Naver->Organic->Facebook->Facebook->Youtube->Organic->Na ... (1629 characters truncated) ... aver->Naver->Naver->Organic->Facebook->Organic->Google->Naver->Facebook->Instagram->Naver->Google->Naver->Google->Facebook->Youtube->Organic->Organic')]

# %%
# %%sql
#
# SELECT usc.*, st.ts, LAG(channel, 1) OVER (PARTITION BY userId ORDER BY ts) prev_channel
# FROM raw_data.user_session_channel usc
# JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# ORDER BY usc.userid, st.ts
# LIMIT 100;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [(27, 'a67c8c9a961b4182688768dd9ba015fe', 'Youtube', datetime.datetime(2019, 5, 1, 17, 3, 59, 957000), None),
#  (27, 'b04c387c8384ca083a71b8da516f65f6', 'Google', datetime.datetime(2019, 5, 2, 19, 21, 30, 280000), 'Youtube'),
#  (27, 'abebb7c39f4b5e46bbcfab2b565ef32b', 'Naver', datetime.datetime(2019, 5, 3, 20, 38, 40, 730000), 'Google'),
#  (27, 'ab49ef78e2877bfd2c2bfa738e459bf0', 'Facebook', datetime.datetime(2019, 5, 4, 21, 48, 7, 300000), 'Naver'),
#  (27, 'f740c8d9c193f16d8a07d3a8a751d13f', 'Facebook', datetime.datetime(2019, 5, 5, 18, 15, 30, 540000), 'Facebook'),
#  (27, 'ef452c63f81d0105dd4486f775adec81', 'Google', datetime.datetime(2019, 5, 6, 17, 49, 15, 437000), 'Facebook'),
#  (27, 'd7f426ccbc6db7e235c57958c21c5dfa', 'Google', datetime.datetime(2019, 5, 7, 20, 41, 25, 293000), 'Google'),
#  (27, 'df334b223e699294764c2bb7ae40d8db', 'Facebook', datetime.datetime(2019, 5, 8, 17, 35, 16, 440000), 'Google'),
#  (27, '02c27682b80b462437ba4efc71267562', 'Organic', datetime.datetime(2019, 5, 9, 19, 57, 40, 37000), 'Facebook'),
#  (27, 'ca9541826e97c4530b07dda2eba0e013', 'Organic', datetime.datetime(2019, 5, 10, 17, 57, 10, 207000), 'Organic'),
#  (27, '09853c7fb1d3f8ee67a61b6bf4a7f8e6', 'Organic', datetime.datetime(2019, 5, 11, 20, 23, 32, 920000), 'Organic'),
#  (27, '9c16f6606460d1543759fc966b9bb797', 'Organic', datetime.datetime(2019, 5, 11, 20, 28, 26, 313000), 'Organic'),
#  (27, '5f8b73c0d4b1bf60dd7173b660b87c29', 'Facebook', datetime.datetime(2019, 5, 12, 21, 24, 11, 560000), 'Organic'),
#  (27, 'b16574c54c98b9512edbecb8fa4f47f2', 'Naver', datetime.datetime(2019, 5, 12, 21, 32, 47, 7000), 'Facebook'),
#  (27, 'e97986091ee430b881ba8fc9755a64a8', 'Naver', datetime.datetime(2019, 5, 13, 22, 15, 47, 763000), 'Naver'),
#  (27, '8d1de7457fa769ece8d93a13a59c8552', 'Organic', datetime.datetime(2019, 5, 14, 19, 48, 34, 197000), 'Naver'),
#  (27, 'e95a45d0b1f5afdf0ab9cde82b4b1d06', 'Google', datetime.datetime(2019, 5, 15, 17, 19, 48, 473000), 'Organic'),
#  (27, '35adf1ae7eb5734122c84b7a9ea5cc13', 'Instagram', datetime.datetime(2019, 5, 16, 18, 46, 44, 713000), 'Google'),
#  (27, '384cb854644425079baeec43aa82534f', 'Google', datetime.datetime(2019, 5, 17, 23, 30, 8, 503000), 'Instagram'),
#  (27, 'e9074df9d70cb6f30fa378e92edbb490', 'Naver', datetime.datetime(2019, 5, 20, 21, 14, 17, 223000), 'Google'),
#  (27, 'd1f157379ea7e51d4a8c07aff102a43f', 'Facebook', datetime.datetime(2019, 5, 21, 19, 14, 31, 970000), 'Naver'),
#  (27, 'fa60438ac1719d11eb95899af86e27c6', 'Facebook', datetime.datetime(2019, 5, 22, 19, 49, 35, 183000), 'Facebook'),
#  (27, 'd93c96e6a23fff65b91b900aaa541998', 'Facebook', datetime.datetime(2019, 5, 22, 19, 53, 19, 87000), 'Facebook'),
#  (27, '890ff058169b5a1d1a7f07d467f1f57b', 'Facebook', datetime.datetime(2019, 5, 24, 21, 55, 13, 513000), 'Facebook'),
#  (27, '91df814c65a828c59c6217aebd6a27c2', 'Youtube', datetime.datetime(2019, 6, 4, 19, 2, 15, 837000), 'Facebook'),
#  (27, 'ca6d44105c8d58368d11134a0e2146ff', 'Google', datetime.datetime(2019, 6, 5, 20, 11, 40, 597000), 'Youtube'),
#  (27, 'bb83b72bf545e376f3ff9443bda39421', 'Facebook', datetime.datetime(2019, 6, 6, 18, 15, 33, 663000), 'Google'),
#  (27, '1cbd0a834ad09f5650b3536f90478f25', 'Organic', datetime.datetime(2019, 6, 7, 22, 58, 7, 510000), 'Facebook'),
#  (27, '30293457191c29e0d0d7a715d26041bd', 'Naver', datetime.datetime(2019, 6, 8, 17, 56, 34, 733000), 'Organic'),
#  (27, '8aad11ad0535421ef52a534d5cce4bd3', 'Facebook', datetime.datetime(2019, 6, 9, 18, 23, 17, 560000), 'Naver'),
#  (27, '90ecce8d5dad4396f681182cb470872c', 'Youtube', datetime.datetime(2019, 6, 10, 19, 28, 31, 117000), 'Facebook'),
#  (27, 'cbb35954885076becb80ddc715b63713', 'Facebook', datetime.datetime(2019, 6, 11, 17, 14, 19, 757000), 'Youtube'),
#  (27, '8a27c2ddc3d3fe74aa037f4b7d262e34', 'Instagram', datetime.datetime(2019, 6, 12, 17, 30, 43, 637000), 'Facebook'),
#  (27, '9f1974a3c9203cbce1166759bcb7fc0f', 'Youtube', datetime.datetime(2019, 6, 14, 21, 32, 35, 627000), 'Instagram'),
#  (27, '82ce5ed14ce2278cbf483067765be069', 'Organic', datetime.datetime(2019, 6, 15, 18, 59, 28, 643000), 'Youtube'),
#  (27, '6a3eb9a0e11d2e50254bd6e0dd993eba', 'Organic', datetime.datetime(2019, 6, 21, 19, 8, 25, 137000), 'Organic'),
#  (27, '8277ee21b1f8107795126b1e8d803f1a', 'Facebook', datetime.datetime(2019, 6, 22, 18, 13, 57, 810000), 'Organic'),
#  (27, 'aa8f7e46ca13ec4051e4b358eb9273ac', 'Organic', datetime.datetime(2019, 6, 23, 18, 44, 41, 623000), 'Facebook'),
#  (27, 'ca9f9c4764430f980dca8d70e29d8e5e', 'Google', datetime.datetime(2019, 6, 24, 18, 13, 56, 720000), 'Organic'),
#  (27, '9c9304f46197154416dce79e2fb2422a', 'Naver', datetime.datetime(2019, 6, 24, 18, 14, 10, 913000), 'Google'),
#  (27, '33c14ab38a8923e563e17b79e41693ba', 'Facebook', datetime.datetime(2019, 6, 25, 20, 32, 25, 423000), 'Naver'),
#  (27, 'c2a58db8b46ccab0d043e74164407627', 'Naver', datetime.datetime(2019, 6, 26, 21, 6, 59, 173000), 'Facebook'),
#  (27, '879aecb3e6e794603e8c96e2dafca75c', 'Youtube', datetime.datetime(2019, 6, 27, 19, 20, 55, 307000), 'Naver'),
#  (27, 'b7e67bd1951c09018e6a851fb2e7d9ca', 'Google', datetime.datetime(2019, 6, 27, 19, 30, 30, 70000), 'Youtube'),
#  (27, '2bee829bed9516889344bb4a675d7e38', 'Facebook', datetime.datetime(2019, 6, 28, 20, 10, 5, 257000), 'Google'),
#  (27, 'bd01412b3451d57313ac48047f90b14f', 'Organic', datetime.datetime(2019, 8, 8, 17, 31, 34, 597000), 'Facebook'),
#  (27, '319d3166ea5c551f99dd475924788d9a', 'Organic', datetime.datetime(2019, 8, 9, 18, 35, 34, 240000), 'Organic'),
#  (27, '92fe0f14f026db9c6631440f5b5cf0dc', 'Facebook', datetime.datetime(2019, 8, 9, 18, 36, 51, 883000), 'Organic'),
#  (27, '476d9ee280c59ed43b3f813c6d3a44c6', 'Facebook', datetime.datetime(2019, 8, 10, 17, 54, 55, 827000), 'Facebook'),
#  (27, '58caf27a48e7930aefd5437298d64a70', 'Google', datetime.datetime(2019, 8, 11, 20, 34, 47, 867000), 'Facebook'),
#  (27, '039043c90e0bec4f2947ad9778dc35c0', 'Youtube', datetime.datetime(2019, 8, 12, 18, 18, 37, 337000), 'Google'),
#  (27, 'bca0870cfef8e4e835b6ac8cb8b5b9bb', 'Instagram', datetime.datetime(2019, 8, 13, 19, 6, 44, 477000), 'Youtube'),
#  (27, '03114c0c3fae310726281dd79793bcc3', 'Naver', datetime.datetime(2019, 8, 14, 16, 16, 44, 857000), 'Instagram'),
#  (27, '28d74d6b21d68ae455b19876e66a7d5e', 'Organic', datetime.datetime(2019, 8, 15, 21, 26, 42, 373000), 'Naver'),
#  (27, '648fcf4a5db414662ea7c164c534d89e', 'Google', datetime.datetime(2019, 8, 16, 16, 7, 42, 797000), 'Organic'),
#  (27, 'e2d5466377ae503933e23110e5942a3a', 'Instagram', datetime.datetime(2019, 8, 16, 16, 13, 53, 703000), 'Google'),
#  (27, 'f0b8024455e6c0cb3ab7495325afee5c', 'Naver', datetime.datetime(2019, 8, 17, 21, 47, 17, 573000), 'Instagram'),
#  (27, '6fe8465bc8336111639bbb31d3162bc8', 'Organic', datetime.datetime(2019, 8, 18, 20, 54, 31, 667000), 'Naver'),
#  (27, 'a9588e180ff6d0bf6396566a35e9f36f', 'Instagram', datetime.datetime(2019, 8, 19, 20, 41, 32, 300000), 'Organic'),
#  (27, '6201a8c498ddef92d0ac8e9f0fc5b0c1', 'Google', datetime.datetime(2019, 8, 21, 18, 0, 19, 30000), 'Instagram'),
#  (27, 'f489c27798018a004cf82f5caa6a2bd6', 'Facebook', datetime.datetime(2019, 8, 22, 16, 27, 57, 27000), 'Google'),
#  (27, 'e82a71007130c199a90961842d15b339', 'Youtube', datetime.datetime(2019, 8, 23, 19, 30, 43, 77000), 'Facebook'),
#  (27, '839e031f73a030ddf8e92c340337caf1', 'Facebook', datetime.datetime(2019, 8, 24, 19, 21, 51, 437000), 'Youtube'),
#  (27, '8157f8d9e5f3949e8d7225177897751a', 'Instagram', datetime.datetime(2019, 8, 25, 18, 14, 19, 723000), 'Facebook'),
#  (27, '49f3964a40121e8b424ea3861432a77b', 'Naver', datetime.datetime(2019, 8, 26, 19, 45, 23, 483000), 'Instagram'),
#  (27, 'aa0c1c360585020e8fb2d9f34fa25e7b', 'Organic', datetime.datetime(2019, 8, 27, 19, 20, 50, 287000), 'Naver'),
#  (27, '4cf94c3ff0a2ec91ad46d2f076ff59a8', 'Google', datetime.datetime(2019, 8, 28, 19, 50, 14, 450000), 'Organic'),
#  (27, '0cfca7506e27c675cb497d604a72fbcd', 'Facebook', datetime.datetime(2019, 8, 29, 19, 32, 5, 753000), 'Google'),
#  (27, 'e5e0f55fe66ffb0054e25bdb5398098b', 'Instagram', datetime.datetime(2019, 8, 30, 20, 21, 12, 697000), 'Facebook'),
#  (27, '30da596c433c76a09d9b16c8e9c19f08', 'Naver', datetime.datetime(2019, 8, 31, 20, 41, 57, 857000), 'Instagram'),
#  (27, 'b1bb73ed1b44115f5efc8f2d899d4b13', 'Naver', datetime.datetime(2019, 9, 1, 19, 19, 16, 837000), 'Naver'),
#  (27, 'e73de1bd41a06d27b184e9f8c99209e1', 'Google', datetime.datetime(2019, 9, 2, 20, 29, 10, 577000), 'Naver'),
#  (27, 'd77240e883508e09ac5335ddd1e226fd', 'Facebook', datetime.datetime(2019, 9, 3, 18, 21, 5, 610000), 'Google'),
#  (27, 'e8858cb9a3fc30bce8d1b7e992b3fa2b', 'Organic', datetime.datetime(2019, 9, 4, 22, 2, 3, 597000), 'Facebook'),
#  (27, '9437e3994929bc613a9f2b7fe5fb4f9f', 'Naver', datetime.datetime(2019, 9, 5, 20, 59, 38, 967000), 'Organic'),
#  (27, 'd5441b434c4cc05d254ee44ef0331dd8', 'Facebook', datetime.datetime(2019, 9, 6, 17, 40, 30, 313000), 'Naver'),
#  (27, 'da268a78ff158b17e145a4940301394d', 'Organic', datetime.datetime(2019, 9, 7, 18, 7, 26, 930000), 'Facebook'),
#  (27, '32d740249ab62e510dfc6394af0514fa', 'Naver', datetime.datetime(2019, 9, 7, 18, 11, 27, 327000), 'Organic'),
#  (27, 'ac473d1868860bb5f755f31e3ae6a552', 'Google', datetime.datetime(2019, 9, 7, 18, 12, 24, 313000), 'Naver'),
#  (27, '23b667dfda9004cb8af1cf7d82a082b2', 'Instagram', datetime.datetime(2019, 9, 8, 21, 2, 57, 363000), 'Google'),
#  (27, '1001d59c2b2ce9dbc0c5cd2f895caa37', 'Organic', datetime.datetime(2019, 9, 9, 15, 56, 3, 517000), 'Instagram'),
#  (27, '65d71db8c04bb16519da15e01b0fb2d0', 'Youtube', datetime.datetime(2019, 9, 10, 17, 42, 18, 857000), 'Organic'),
#  (27, '10b74c7df29e5be26bf8eb47b66daa53', 'Organic', datetime.datetime(2019, 9, 10, 17, 42, 38, 67000), 'Youtube'),
#  (27, '3c44ee0ba1544062e56072efd77a40c6', 'Facebook', datetime.datetime(2019, 9, 11, 16, 37, 43, 90000), 'Organic'),
#  (27, 'f70098cc80bffdf04af7c9a9c9d0f8b6', 'Instagram', datetime.datetime(2019, 9, 12, 16, 58, 41, 753000), 'Facebook'),
#  (27, '46d73d5eefa09162d46a07a25e304eb3', 'Instagram', datetime.datetime(2019, 9, 13, 20, 49, 24, 993000), 'Instagram'),
#  (27, '91efe58dc7998d49807f2e9be7705b2e', 'Google', datetime.datetime(2019, 9, 14, 18, 7, 40, 140000), 'Instagram'),
#  (27, 'fa1e8b32fa958e2edaabbf3475161d0c', 'Organic', datetime.datetime(2019, 9, 14, 18, 11, 25, 490000), 'Google'),
#  (27, '5056672a836833242f0d04835b231ca7', 'Instagram', datetime.datetime(2019, 9, 15, 20, 39, 15, 717000), 'Organic'),
#  (27, '191406a98580d3aca7b43c1d5b60ecec', 'Organic', datetime.datetime(2019, 9, 16, 15, 7, 20, 580000), 'Instagram'),
#  (27, 'ba59d2f47405b0a7adbefc3f55675a41', 'Youtube', datetime.datetime(2019, 9, 17, 19, 33, 1, 363000), 'Organic'),
#  (27, '209ed5567b7de8d810127caad4f2eeb9', 'Naver', datetime.datetime(2019, 9, 18, 16, 47, 46, 617000), 'Youtube'),
#  (27, '8f391213fdc9a9b0e535d990943cffa7', 'Instagram', datetime.datetime(2019, 9, 18, 16, 49, 42, 650000), 'Naver'),
#  (27, '59acf66ee9debf6a5e9dcff92994afc2', 'Instagram', datetime.datetime(2019, 9, 19, 16, 41, 11, 913000), 'Instagram'),
#  (27, '38f55a3075ec53b4b58de7814c425247', 'Naver', datetime.datetime(2019, 9, 20, 20, 39, 19, 830000), 'Instagram'),
#  (27, '13703fbd8c129b27cbd494d66721415b', 'Organic', datetime.datetime(2019, 9, 21, 19, 53, 13, 673000), 'Naver'),
#  (27, '263f7dadfda23b095c9bb6db65db610a', 'Youtube', datetime.datetime(2019, 9, 22, 19, 44, 58, 203000), 'Organic'),
#  (27, 'eeafc9fb83ef2e593ae231987545ce5f', 'Naver', datetime.datetime(2019, 9, 22, 19, 45, 23, 567000), 'Youtube'),
#  (27, 'fb97fe66af9b3284b34c31a8c77fd2f2', 'Youtube', datetime.datetime(2019, 9, 23, 17, 32, 43, 810000), 'Naver'),
#  (27, 'cb17638efa569ae749eb4e4aaf275438', 'Instagram', datetime.datetime(2019, 9, 24, 18, 59, 35, 473000), 'Youtube')]

# %%
# %%sql
#
# SELECT usc.*, st.ts, LAG(channel, 1) OVER (PARTITION BY userId ORDER BY ts DESC) prev_channel
# FROM raw_data.user_session_channel usc
# JOIN raw_data.session_timestamp st ON usc.sessionid = st.sessionid
# ORDER BY usc.userid, st.ts
# LIMIT 100;
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 100 rows affected.
# [(27, 'a67c8c9a961b4182688768dd9ba015fe', 'Youtube', datetime.datetime(2019, 5, 1, 17, 3, 59, 957000), 'Google'),
#  (27, 'b04c387c8384ca083a71b8da516f65f6', 'Google', datetime.datetime(2019, 5, 2, 19, 21, 30, 280000), 'Naver'),
#  (27, 'abebb7c39f4b5e46bbcfab2b565ef32b', 'Naver', datetime.datetime(2019, 5, 3, 20, 38, 40, 730000), 'Facebook'),
#  (27, 'ab49ef78e2877bfd2c2bfa738e459bf0', 'Facebook', datetime.datetime(2019, 5, 4, 21, 48, 7, 300000), 'Facebook'),
#  (27, 'f740c8d9c193f16d8a07d3a8a751d13f', 'Facebook', datetime.datetime(2019, 5, 5, 18, 15, 30, 540000), 'Google'),
#  (27, 'ef452c63f81d0105dd4486f775adec81', 'Google', datetime.datetime(2019, 5, 6, 17, 49, 15, 437000), 'Google'),
#  (27, 'd7f426ccbc6db7e235c57958c21c5dfa', 'Google', datetime.datetime(2019, 5, 7, 20, 41, 25, 293000), 'Facebook'),
#  (27, 'df334b223e699294764c2bb7ae40d8db', 'Facebook', datetime.datetime(2019, 5, 8, 17, 35, 16, 440000), 'Organic'),
#  (27, '02c27682b80b462437ba4efc71267562', 'Organic', datetime.datetime(2019, 5, 9, 19, 57, 40, 37000), 'Organic'),
#  (27, 'ca9541826e97c4530b07dda2eba0e013', 'Organic', datetime.datetime(2019, 5, 10, 17, 57, 10, 207000), 'Organic'),
#  (27, '09853c7fb1d3f8ee67a61b6bf4a7f8e6', 'Organic', datetime.datetime(2019, 5, 11, 20, 23, 32, 920000), 'Organic'),
#  (27, '9c16f6606460d1543759fc966b9bb797', 'Organic', datetime.datetime(2019, 5, 11, 20, 28, 26, 313000), 'Facebook'),
#  (27, '5f8b73c0d4b1bf60dd7173b660b87c29', 'Facebook', datetime.datetime(2019, 5, 12, 21, 24, 11, 560000), 'Naver'),
#  (27, 'b16574c54c98b9512edbecb8fa4f47f2', 'Naver', datetime.datetime(2019, 5, 12, 21, 32, 47, 7000), 'Naver'),
#  (27, 'e97986091ee430b881ba8fc9755a64a8', 'Naver', datetime.datetime(2019, 5, 13, 22, 15, 47, 763000), 'Organic'),
#  (27, '8d1de7457fa769ece8d93a13a59c8552', 'Organic', datetime.datetime(2019, 5, 14, 19, 48, 34, 197000), 'Google'),
#  (27, 'e95a45d0b1f5afdf0ab9cde82b4b1d06', 'Google', datetime.datetime(2019, 5, 15, 17, 19, 48, 473000), 'Instagram'),
#  (27, '35adf1ae7eb5734122c84b7a9ea5cc13', 'Instagram', datetime.datetime(2019, 5, 16, 18, 46, 44, 713000), 'Google'),
#  (27, '384cb854644425079baeec43aa82534f', 'Google', datetime.datetime(2019, 5, 17, 23, 30, 8, 503000), 'Naver'),
#  (27, 'e9074df9d70cb6f30fa378e92edbb490', 'Naver', datetime.datetime(2019, 5, 20, 21, 14, 17, 223000), 'Facebook'),
#  (27, 'd1f157379ea7e51d4a8c07aff102a43f', 'Facebook', datetime.datetime(2019, 5, 21, 19, 14, 31, 970000), 'Facebook'),
#  (27, 'fa60438ac1719d11eb95899af86e27c6', 'Facebook', datetime.datetime(2019, 5, 22, 19, 49, 35, 183000), 'Facebook'),
#  (27, 'd93c96e6a23fff65b91b900aaa541998', 'Facebook', datetime.datetime(2019, 5, 22, 19, 53, 19, 87000), 'Facebook'),
#  (27, '890ff058169b5a1d1a7f07d467f1f57b', 'Facebook', datetime.datetime(2019, 5, 24, 21, 55, 13, 513000), 'Youtube'),
#  (27, '91df814c65a828c59c6217aebd6a27c2', 'Youtube', datetime.datetime(2019, 6, 4, 19, 2, 15, 837000), 'Google'),
#  (27, 'ca6d44105c8d58368d11134a0e2146ff', 'Google', datetime.datetime(2019, 6, 5, 20, 11, 40, 597000), 'Facebook'),
#  (27, 'bb83b72bf545e376f3ff9443bda39421', 'Facebook', datetime.datetime(2019, 6, 6, 18, 15, 33, 663000), 'Organic'),
#  (27, '1cbd0a834ad09f5650b3536f90478f25', 'Organic', datetime.datetime(2019, 6, 7, 22, 58, 7, 510000), 'Naver'),
#  (27, '30293457191c29e0d0d7a715d26041bd', 'Naver', datetime.datetime(2019, 6, 8, 17, 56, 34, 733000), 'Facebook'),
#  (27, '8aad11ad0535421ef52a534d5cce4bd3', 'Facebook', datetime.datetime(2019, 6, 9, 18, 23, 17, 560000), 'Youtube'),
#  (27, '90ecce8d5dad4396f681182cb470872c', 'Youtube', datetime.datetime(2019, 6, 10, 19, 28, 31, 117000), 'Facebook'),
#  (27, 'cbb35954885076becb80ddc715b63713', 'Facebook', datetime.datetime(2019, 6, 11, 17, 14, 19, 757000), 'Instagram'),
#  (27, '8a27c2ddc3d3fe74aa037f4b7d262e34', 'Instagram', datetime.datetime(2019, 6, 12, 17, 30, 43, 637000), 'Youtube'),
#  (27, '9f1974a3c9203cbce1166759bcb7fc0f', 'Youtube', datetime.datetime(2019, 6, 14, 21, 32, 35, 627000), 'Organic'),
#  (27, '82ce5ed14ce2278cbf483067765be069', 'Organic', datetime.datetime(2019, 6, 15, 18, 59, 28, 643000), 'Organic'),
#  (27, '6a3eb9a0e11d2e50254bd6e0dd993eba', 'Organic', datetime.datetime(2019, 6, 21, 19, 8, 25, 137000), 'Facebook'),
#  (27, '8277ee21b1f8107795126b1e8d803f1a', 'Facebook', datetime.datetime(2019, 6, 22, 18, 13, 57, 810000), 'Organic'),
#  (27, 'aa8f7e46ca13ec4051e4b358eb9273ac', 'Organic', datetime.datetime(2019, 6, 23, 18, 44, 41, 623000), 'Google'),
#  (27, 'ca9f9c4764430f980dca8d70e29d8e5e', 'Google', datetime.datetime(2019, 6, 24, 18, 13, 56, 720000), 'Naver'),
#  (27, '9c9304f46197154416dce79e2fb2422a', 'Naver', datetime.datetime(2019, 6, 24, 18, 14, 10, 913000), 'Facebook'),
#  (27, '33c14ab38a8923e563e17b79e41693ba', 'Facebook', datetime.datetime(2019, 6, 25, 20, 32, 25, 423000), 'Naver'),
#  (27, 'c2a58db8b46ccab0d043e74164407627', 'Naver', datetime.datetime(2019, 6, 26, 21, 6, 59, 173000), 'Youtube'),
#  (27, '879aecb3e6e794603e8c96e2dafca75c', 'Youtube', datetime.datetime(2019, 6, 27, 19, 20, 55, 307000), 'Google'),
#  (27, 'b7e67bd1951c09018e6a851fb2e7d9ca', 'Google', datetime.datetime(2019, 6, 27, 19, 30, 30, 70000), 'Facebook'),
#  (27, '2bee829bed9516889344bb4a675d7e38', 'Facebook', datetime.datetime(2019, 6, 28, 20, 10, 5, 257000), 'Organic'),
#  (27, 'bd01412b3451d57313ac48047f90b14f', 'Organic', datetime.datetime(2019, 8, 8, 17, 31, 34, 597000), 'Organic'),
#  (27, '319d3166ea5c551f99dd475924788d9a', 'Organic', datetime.datetime(2019, 8, 9, 18, 35, 34, 240000), 'Facebook'),
#  (27, '92fe0f14f026db9c6631440f5b5cf0dc', 'Facebook', datetime.datetime(2019, 8, 9, 18, 36, 51, 883000), 'Facebook'),
#  (27, '476d9ee280c59ed43b3f813c6d3a44c6', 'Facebook', datetime.datetime(2019, 8, 10, 17, 54, 55, 827000), 'Google'),
#  (27, '58caf27a48e7930aefd5437298d64a70', 'Google', datetime.datetime(2019, 8, 11, 20, 34, 47, 867000), 'Youtube'),
#  (27, '039043c90e0bec4f2947ad9778dc35c0', 'Youtube', datetime.datetime(2019, 8, 12, 18, 18, 37, 337000), 'Instagram'),
#  (27, 'bca0870cfef8e4e835b6ac8cb8b5b9bb', 'Instagram', datetime.datetime(2019, 8, 13, 19, 6, 44, 477000), 'Naver'),
#  (27, '03114c0c3fae310726281dd79793bcc3', 'Naver', datetime.datetime(2019, 8, 14, 16, 16, 44, 857000), 'Organic'),
#  (27, '28d74d6b21d68ae455b19876e66a7d5e', 'Organic', datetime.datetime(2019, 8, 15, 21, 26, 42, 373000), 'Google'),
#  (27, '648fcf4a5db414662ea7c164c534d89e', 'Google', datetime.datetime(2019, 8, 16, 16, 7, 42, 797000), 'Instagram'),
#  (27, 'e2d5466377ae503933e23110e5942a3a', 'Instagram', datetime.datetime(2019, 8, 16, 16, 13, 53, 703000), 'Naver'),
#  (27, 'f0b8024455e6c0cb3ab7495325afee5c', 'Naver', datetime.datetime(2019, 8, 17, 21, 47, 17, 573000), 'Organic'),
#  (27, '6fe8465bc8336111639bbb31d3162bc8', 'Organic', datetime.datetime(2019, 8, 18, 20, 54, 31, 667000), 'Instagram'),
#  (27, 'a9588e180ff6d0bf6396566a35e9f36f', 'Instagram', datetime.datetime(2019, 8, 19, 20, 41, 32, 300000), 'Google'),
#  (27, '6201a8c498ddef92d0ac8e9f0fc5b0c1', 'Google', datetime.datetime(2019, 8, 21, 18, 0, 19, 30000), 'Facebook'),
#  (27, 'f489c27798018a004cf82f5caa6a2bd6', 'Facebook', datetime.datetime(2019, 8, 22, 16, 27, 57, 27000), 'Youtube'),
#  (27, 'e82a71007130c199a90961842d15b339', 'Youtube', datetime.datetime(2019, 8, 23, 19, 30, 43, 77000), 'Facebook'),
#  (27, '839e031f73a030ddf8e92c340337caf1', 'Facebook', datetime.datetime(2019, 8, 24, 19, 21, 51, 437000), 'Instagram'),
#  (27, '8157f8d9e5f3949e8d7225177897751a', 'Instagram', datetime.datetime(2019, 8, 25, 18, 14, 19, 723000), 'Naver'),
#  (27, '49f3964a40121e8b424ea3861432a77b', 'Naver', datetime.datetime(2019, 8, 26, 19, 45, 23, 483000), 'Organic'),
#  (27, 'aa0c1c360585020e8fb2d9f34fa25e7b', 'Organic', datetime.datetime(2019, 8, 27, 19, 20, 50, 287000), 'Google'),
#  (27, '4cf94c3ff0a2ec91ad46d2f076ff59a8', 'Google', datetime.datetime(2019, 8, 28, 19, 50, 14, 450000), 'Facebook'),
#  (27, '0cfca7506e27c675cb497d604a72fbcd', 'Facebook', datetime.datetime(2019, 8, 29, 19, 32, 5, 753000), 'Instagram'),
#  (27, 'e5e0f55fe66ffb0054e25bdb5398098b', 'Instagram', datetime.datetime(2019, 8, 30, 20, 21, 12, 697000), 'Naver'),
#  (27, '30da596c433c76a09d9b16c8e9c19f08', 'Naver', datetime.datetime(2019, 8, 31, 20, 41, 57, 857000), 'Naver'),
#  (27, 'b1bb73ed1b44115f5efc8f2d899d4b13', 'Naver', datetime.datetime(2019, 9, 1, 19, 19, 16, 837000), 'Google'),
#  (27, 'e73de1bd41a06d27b184e9f8c99209e1', 'Google', datetime.datetime(2019, 9, 2, 20, 29, 10, 577000), 'Facebook'),
#  (27, 'd77240e883508e09ac5335ddd1e226fd', 'Facebook', datetime.datetime(2019, 9, 3, 18, 21, 5, 610000), 'Organic'),
#  (27, 'e8858cb9a3fc30bce8d1b7e992b3fa2b', 'Organic', datetime.datetime(2019, 9, 4, 22, 2, 3, 597000), 'Naver'),
#  (27, '9437e3994929bc613a9f2b7fe5fb4f9f', 'Naver', datetime.datetime(2019, 9, 5, 20, 59, 38, 967000), 'Facebook'),
#  (27, 'd5441b434c4cc05d254ee44ef0331dd8', 'Facebook', datetime.datetime(2019, 9, 6, 17, 40, 30, 313000), 'Organic'),
#  (27, 'da268a78ff158b17e145a4940301394d', 'Organic', datetime.datetime(2019, 9, 7, 18, 7, 26, 930000), 'Naver'),
#  (27, '32d740249ab62e510dfc6394af0514fa', 'Naver', datetime.datetime(2019, 9, 7, 18, 11, 27, 327000), 'Google'),
#  (27, 'ac473d1868860bb5f755f31e3ae6a552', 'Google', datetime.datetime(2019, 9, 7, 18, 12, 24, 313000), 'Instagram'),
#  (27, '23b667dfda9004cb8af1cf7d82a082b2', 'Instagram', datetime.datetime(2019, 9, 8, 21, 2, 57, 363000), 'Organic'),
#  (27, '1001d59c2b2ce9dbc0c5cd2f895caa37', 'Organic', datetime.datetime(2019, 9, 9, 15, 56, 3, 517000), 'Youtube'),
#  (27, '65d71db8c04bb16519da15e01b0fb2d0', 'Youtube', datetime.datetime(2019, 9, 10, 17, 42, 18, 857000), 'Organic'),
#  (27, '10b74c7df29e5be26bf8eb47b66daa53', 'Organic', datetime.datetime(2019, 9, 10, 17, 42, 38, 67000), 'Facebook'),
#  (27, '3c44ee0ba1544062e56072efd77a40c6', 'Facebook', datetime.datetime(2019, 9, 11, 16, 37, 43, 90000), 'Instagram'),
#  (27, 'f70098cc80bffdf04af7c9a9c9d0f8b6', 'Instagram', datetime.datetime(2019, 9, 12, 16, 58, 41, 753000), 'Instagram'),
#  (27, '46d73d5eefa09162d46a07a25e304eb3', 'Instagram', datetime.datetime(2019, 9, 13, 20, 49, 24, 993000), 'Google'),
#  (27, '91efe58dc7998d49807f2e9be7705b2e', 'Google', datetime.datetime(2019, 9, 14, 18, 7, 40, 140000), 'Organic'),
#  (27, 'fa1e8b32fa958e2edaabbf3475161d0c', 'Organic', datetime.datetime(2019, 9, 14, 18, 11, 25, 490000), 'Instagram'),
#  (27, '5056672a836833242f0d04835b231ca7', 'Instagram', datetime.datetime(2019, 9, 15, 20, 39, 15, 717000), 'Organic'),
#  (27, '191406a98580d3aca7b43c1d5b60ecec', 'Organic', datetime.datetime(2019, 9, 16, 15, 7, 20, 580000), 'Youtube'),
#  (27, 'ba59d2f47405b0a7adbefc3f55675a41', 'Youtube', datetime.datetime(2019, 9, 17, 19, 33, 1, 363000), 'Naver'),
#  (27, '209ed5567b7de8d810127caad4f2eeb9', 'Naver', datetime.datetime(2019, 9, 18, 16, 47, 46, 617000), 'Instagram'),
#  (27, '8f391213fdc9a9b0e535d990943cffa7', 'Instagram', datetime.datetime(2019, 9, 18, 16, 49, 42, 650000), 'Instagram'),
#  (27, '59acf66ee9debf6a5e9dcff92994afc2', 'Instagram', datetime.datetime(2019, 9, 19, 16, 41, 11, 913000), 'Naver'),
#  (27, '38f55a3075ec53b4b58de7814c425247', 'Naver', datetime.datetime(2019, 9, 20, 20, 39, 19, 830000), 'Organic'),
#  (27, '13703fbd8c129b27cbd494d66721415b', 'Organic', datetime.datetime(2019, 9, 21, 19, 53, 13, 673000), 'Youtube'),
#  (27, '263f7dadfda23b095c9bb6db65db610a', 'Youtube', datetime.datetime(2019, 9, 22, 19, 44, 58, 203000), 'Naver'),
#  (27, 'eeafc9fb83ef2e593ae231987545ce5f', 'Naver', datetime.datetime(2019, 9, 22, 19, 45, 23, 567000), 'Youtube'),
#  (27, 'fb97fe66af9b3284b34c31a8c77fd2f2', 'Youtube', datetime.datetime(2019, 9, 23, 17, 32, 43, 810000), 'Instagram'),
#  (27, 'cb17638efa569ae749eb4e4aaf275438', 'Instagram', datetime.datetime(2019, 9, 24, 18, 59, 35, 473000), 'Naver')]

# %% [markdown]
# ### JSON parsing 함수

# %%
# %%sql
#
# SELECT JSON_EXTRACT_PATH_TEXT('{"f2":{"f3": "1"},"f4":{"f5":"99","f6":"star"}}','f4', 'f6');
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('star',)]

# %%
# %%sql
#
# SELECT JSON_EXTRACT_PATH_TEXT('{"f2":{"f3": "1"},"f4":{"f5":"99","f6":"star"}}','f4');
# Out:
#  * postgresql://guest:***@learnde.cduaw970ssvt.ap-northeast-2.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('{"f5":"99","f6":"star"}',)]
